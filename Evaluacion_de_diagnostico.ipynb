# %% [markdown]
# Evaluación de Diagnostico - Tomás Fernández Tagle
#
# A continuacion se limpiara la base de datos a trabajar segun lo realizado en la siguente pagina: https://www.kaggle.com/code/prathamsharma123/clean-raw-json-tweets-data

# %%
# Importing required libraries

import pandas as pd
from pandas.io.json import json_normalize
import warnings
warnings.filterwarnings("ignore")

# %%
# Read JSON file containing tweets data and removce tweets not in English

raw_tweets = pd.read_json(r'/content/farmers-protest-tweets-2021-03-5.json', lines=True)
raw_tweets = raw_tweets[raw_tweets['lang']=='en']
print("Shape: ", raw_tweets.shape)
raw_tweets.head(5)

# %%
# Normalize 'user' field

users = json_normalize(raw_tweets['user'])
users.drop(['description', 'linkTcourl'], axis=1, inplace=True)
users.rename(columns={'id':'userId', 'url':'profileUrl'}, inplace=True)

# %%
# Create DataFrame and remove duplicates

users = pd.DataFrame(users)
users.drop_duplicates(subset=['userId'], inplace=True)

# %%
# Transform 'raw_tweets' DataFrame

# Add column for 'userId'
user_id = []
for user in raw_tweets['user']:
    uid = user['id']
    user_id.append(uid)
raw_tweets['userId'] = user_id

# Remove less important columns
cols = ['url', 'date', 'renderedContent', 'id', 'userId', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount', 'source', 'media', 'retweetedTweet', 'quotedTweet', 'mentionedUsers']
tweets = raw_tweets[cols]
tweets.rename(columns={'id':'tweetId', 'url':'tweetUrl'}, inplace=True)

# %%
# Convert to DataFrame, remove duplicates and keep only English tweets

tweets = pd.DataFrame(tweets)
tweets.drop_duplicates(subset=['tweetId'], inplace=True)

# %%
tweets = pd.DataFrame(tweets)
tweets = tweets.sort_values("retweetCount", ascending=False)
tweets.head(10)
# Out:
#                                                 tweetUrl  \
# 29485  https://twitter.com/sushant_says/status/137259...
# 29582  https://twitter.com/saahilmenghani/status/1372...
# 10107  https://twitter.com/saahilmenghani/status/1375...
# 19658  https://twitter.com/MeghUpdates/status/1374021...
# 29850  https://twitter.com/Kisanektamorcha/status/137...
# 3082   https://twitter.com/saahilmenghani/status/1376...
# 15080  https://twitter.com/indijaswaloye/status/13747...
# 29113  https://twitter.com/RaviSinghKA/status/1372707...
# 5270   https://twitter.com/RaviSinghKA/status/1375901...
# 7335   https://twitter.com/jasdhaliwal349/status/1375...
#
#                            date  \
# 29485 2021-03-18 16:52:08+00:00
# 29582 2021-03-18 15:29:30+00:00
# 10107 2021-03-26 05:22:08+00:00
# 19658 2021-03-22 15:35:15+00:00
# 29850 2021-03-18 12:45:02+00:00
# 3082  2021-03-28 16:11:39+00:00
# 15080 2021-03-24 15:25:01+00:00
# 29113 2021-03-19 00:33:51+00:00
# 5270  2021-03-27 20:02:47+00:00
# 7335  2021-03-27 03:24:33+00:00
#
#                                          renderedContent              tweetId  \
# 29485  I am back #FarmersProtest #FreeAllPoliticalPri...  1372591661490917377
# 29582  112 days, #300DeathsAtProtest.\n\n#GodiMedia i...  1372570866404397059
# 10107  #BharatBandh's impact visible in Andhra Prades...  1375317119089266690
# 19658  National Highways Authority of India (NHAI) ha...  1374021864926842885
# 29850  Farmers are not only providing food to nearby ...  1372529475821338626
# 3082   #Breaking\n\n👉Zee Owner Subhash Chandra had an...  1376205351058464768
# 15080  Retweet \n\n#FarmersProtest \n#NoVoteToBJP htt...  1374744067062427650
# 29113  Why are Panjabi singers supporting @ZeeTV who ...  1372707855799873540
# 5270   WARNING: 🚨 Partial Nudity !\n\nBJP MLA from Ab...  1375901131986075651
# 7335   May God give strength and will power to all th...  1375649917121650690
#
#                     userId  replyCount  retweetCount  likeCount  quoteCount  \
# 29485            185609127         339          2797      18453          93
# 29582             79178279          68          1647       3906          70
# 10107             79178279          96          1524       3076          80
# 19658  1109163883082637312         171          1439       4644          72
# 29850  1338536920066879488          55          1283       3301          65
# 3082              79178279          77          1220       2854          58
# 15080  1370283728539328517         155          1073       1894          90
# 29113           2347762888         199          1037       2565         109
# 5270            2347762888         386           985       5054          93
# 7335   1333529163123212290          24           865        703          29
#
#                                                   source  \
# 29485  <a href="http://twitter.com/download/iphone" r...
# 29582  <a href="http://twitter.com/download/android" ...
# 10107  <a href="http://twitter.com/download/android" ...
# 19658  <a href="http://twitter.com/download/android" ...
# 29850  <a href="https://mobile.twitter.com" rel="nofo...
# 3082   <a href="https://studio.twitter.com" rel="nofo...
# 15080  <a href="http://twitter.com/download/android" ...
# 29113  <a href="http://twitter.com/download/iphone" r...
# 5270   <a href="http://twitter.com/download/iphone" r...
# 7335   <a href="http://twitter.com/download/iphone" r...
#
#                                                    media  retweetedTweet  \
# 29485                                               None             NaN
# 29582                                               None             NaN
# 10107  [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 19658                                               None             NaN
# 29850  [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 3082   [{'thumbnailUrl': 'https://pbs.twimg.com/ampli...             NaN
# 15080  [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 29113                                               None             NaN
# 5270   [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
# 7335   [{'previewUrl': 'https://pbs.twimg.com/media/E...             NaN
#
#                                              quotedTweet  \
# 29485                                               None
# 29582                                               None
# 10107                                               None
# 19658                                               None
# 29850                                               None
# 3082                                                None
# 15080                                               None
# 29113  {'url': 'https://twitter.com/GiantsKisaan/stat...
# 5270                                                None
# 7335                                                None
#
#                                           mentionedUsers
# 29485                                               None
# 29582                                               None
# 10107                                               None
# 19658                                               None
# 29850                                               None
# 3082                                                None
# 15080                                               None
# 29113  [{'username': 'ZeeTV', 'displayname': 'ZeeTV',...
# 5270                                                None
# 7335                                                None

# %%
users = pd.DataFrame(users)
users = users.sort_values("mediaCount", ascending=False)
users.head(10)
# Out:
#              username                                 displayname  \
# 901              ndtv                                        NDTV
# 1392         htTweets                             Hindustan Times
# 3163     timesofindia                          The Times Of India
# 9547       IndiaToday                                  IndiaToday
# 3575        yespunjab  YesPunjab.com (For Punjabi follow @BawaHs)
# 846               dna                                         DNA
# 21636      ians_india                                 IANS Tweets
# 18106  BloombergQuint                              BloombergQuint
# 3266     uniindianews                        United News of India
# 2304        WeForNews                                 We For News
#
#                    userId                                     rawDescription  \
# 901              37034483  Breaking news alerts from India.\n\nInstagram:...
# 1392             36327407  One of India's largest media companies. Latest...
# 3163            134758540  News. Views. Analysis. Conversations. India’s ...
# 9547             19897138  Brings you news breaks: Exclusive political, e...
# 3575            224961966  https://t.co/L8t5kU2S6h #News #Entertainment #...
# 846              17710740  Follow us for news, photos, videos and the lat...
# 21636           141584822            India's largest independent News Agency
# 18106  714731566828793857  #India’s premier multi-platform #business and ...
# 3266           3232584426  Official twitter handle of UNI - India's premi...
# 2304           3168249863  News. Trends. Views. Insights. India and World...
#
#                                          descriptionUrls  verified  \
# 901    [{'text': 'instagram.com/ndtv', 'url': 'http:/...      True
